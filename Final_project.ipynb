# %%
import pandas as pd

def calculate_quarterly_returns(data):
    data['Dates'] = pd.to_datetime(data['Dates'])
    data.set_index('Dates', inplace=True)

    # Calculate weekly returns
    weekly_returns = data.pct_change()

    # Calculate quarterly returns
    quarterly_returns = weekly_returns.rolling(window=4).agg(lambda x: (1 + x).prod() - 1)

    return quarterly_returns

# Read the dataset from Excel file
df = pd.read_csv("industry.csv")

# Calculate Quarterly Returns
quarterly_returns_df = calculate_quarterly_returns(df)
display(quarterly_returns_df)
# Out:
#               S&P500  Healthcare  Materials  Financials  \
# Dates
# 1999-11-05       NaN         NaN        NaN         NaN
# 1999-11-12       NaN         NaN        NaN         NaN
# 1999-11-19       NaN         NaN        NaN         NaN
# 1999-11-26       NaN         NaN        NaN         NaN
# 1999-12-03  0.047355   -0.027343   0.010516   -0.036746
# ...              ...         ...        ...         ...
# 2022-11-04  0.036886    0.066883   0.085956    0.098149
# 2022-11-11  0.115500    0.076555   0.192118    0.158870
# 2022-11-18  0.058356    0.063153   0.105562    0.098673
# 2022-11-25  0.033816    0.032459   0.101521    0.056843
# 2022-12-02  0.081933    0.069094   0.110674    0.059128
#
#             Consumer Discretionary  Consumer Staples  Information Technology  \
# Dates
# 1999-11-05                     NaN               NaN                     NaN
# 1999-11-12                     NaN               NaN                     NaN
# ...
